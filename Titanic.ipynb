# %% [markdown]
# <a href="https://colab.research.google.com/github/kra2839/2025-1-myclass-BDA/blob/main/Titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import pandas as pd
import numpy as np

print(sys.version)
print(pd.__version__)
print(np.__version__)
# Out:
# 3.11.12 (main, Apr  9 2025, 08:55:54) [GCC 11.4.0]
# 2.2.2
# 2.0.2

# %%
# !pip install koreanize_matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 23.4 MB/s eta 0:00:00
# ...

# %%
# %config InlineBackend.figure_format = 'retina'

# %%
import seaborn as sns

titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %% [markdown]
# # 성별에 따른 승객 수

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("whitegrid")
sns.countplot(data=titanic, x="sex", hue="sex", palette="pastel", edgecolor="black", legend=False)
plt.title("Passenger Count by Sex")
plt.xlabel("Sex")
plt.ylabel("Count")
plt.tight_layout()
plt.show()

# %% [markdown]
# # 객실 등급 별 승객 수

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("whitegrid")

sns.countplot(data=titanic, x="class", palette="Set2", edgecolor="black")

plt.title("Number of Passengers by Class", fontsize=14)
plt.xlabel("Class", fontsize=12)
plt.ylabel("Passenger Count", fontsize=12)

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-8-2b674b33cc34>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=titanic, x="class", palette="Set2", edgecolor="black")

# %% [markdown]
# # 선실 층 별 승객 수

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("whitegrid")

sns.countplot(data=titanic, x="deck", palette="Set3", edgecolor="black")

plt.title("Passenger Count by Deck", fontsize=14)
plt.xlabel("Deck", fontsize=12)
plt.ylabel("Count", fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-9-7debf0daf8f5>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=titanic, x="deck", palette="Set3", edgecolor="black")

# %% [markdown]
# # 객실 등급에 따른 생존 여부 별 승객 수

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("whitegrid")

sns.countplot(data=titanic, x='class', hue='alive', palette='Set2', edgecolor='black')

plt.title("Survival Count by Passenger Class", fontsize=14)
plt.xlabel("Passenger Class", fontsize=12)
plt.ylabel("Count", fontsize=12)
plt.legend(title="Survived")
plt.tight_layout()
plt.show()

# %% [markdown]
# # 성별에 따른 평균 생존률

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("whitegrid")

plt.figure(figsize=(6, 5))
ax = sns.barplot(data=titanic, x="sex", y="survived", hue="sex", palette="pastel", edgecolor="black", legend=False)

plt.title("Average Survival Rate by Sex", fontsize=16, weight="bold")
plt.xlabel("Sex", fontsize=13)
plt.ylabel("Survival Rate", fontsize=13)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# # 객실 등급과 성별에 따른 평균 탑승 비용 비교

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("whitegrid")
plt.figure(figsize=(8,6))

ax = sns.barplot(data=titanic, x="class", y="fare", hue="sex", palette="Set2", edgecolor="black")

plt.title("Average Fare by Passenger Class and Sex", fontsize=16, weight="bold")
plt.xlabel("Passenger Class", fontsize=14)
plt.ylabel("Average Fare", fontsize=14)

plt.legend(title="Sex", fontsize=12, title_fontsize=13)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# # 선실 층별 객실 등급에 따른 평균 탑승 요금 비교

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("whitegrid")
plt.figure(figsize=(10,6))

ax = sns.barplot(data=titanic, x="deck", y="fare", hue="class", palette="Set3", edgecolor="black")

plt.title("Average Fare by Deck and Passenger Class", fontsize=16, weight="bold")
plt.xlabel("Deck", fontsize=14)
plt.ylabel("Average Fare", fontsize=14)

plt.legend(title="Passenger Class", fontsize=12, title_fontsize=13)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# # 선실 층과 객실 등급에 따른 평균 생존률 비교 그래프

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("whitegrid")
plt.figure(figsize=(10,6))

ax = sns.barplot(data=titanic, x="deck", y="survived", hue="class", palette="Set2", edgecolor="black")

plt.title("Average Survival Rate by Deck and Passenger Class", fontsize=16, weight="bold")
plt.xlabel("Deck", fontsize=14)
plt.ylabel("Average Survival Rate", fontsize=14)

plt.legend(title="Passenger Class", fontsize=12, title_fontsize=13)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##승객의 선실 등급 (1등석, 2등석, 3등석)

# %%
titanic["pclass"]
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: pclass, Length: 891, dtype: int64

# %% [markdown]
# # 1등석 승객만 추출

# %%
titanic[titanic["pclass"] == 1]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 11          1       1  female  58.0      0      0  26.5500        S  First
# 23          1       1    male  28.0      0      0  35.5000        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# # 여성 승객만

# %%
titanic[titanic["sex"] == "female"]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# # 나이가 18세 미만인 승객

# %%
titanic[titanic["age"] < 18]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 7           0       3    male   2.0      3      1  21.0750        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# 10          1       3  female   4.0      1      1  16.7000        S   Third
# 14          0       3  female  14.0      0      0   7.8542        S   Third
# 16          0       3    male   2.0      4      1  29.1250        Q   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 850         0       3    male   4.0      4      2  31.2750        S   Third
# 852         0       3  female   9.0      1      1  15.2458        C   Third
# 853         1       1  female  16.0      0      1  39.4000        S   First
# 869         1       3    male   4.0      1      1  11.1333        S   Third
# 875         1       3  female  15.0      0      0   7.2250        C   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# # 성별, 나이, 생존 여부만 보기

# %%
titanic[["sex", "age", "survived"]]
# Out:
#         sex   age  survived
# 0      male  22.0         0
# 1    female  38.0         1
# 2    female  26.0         1
# 3    female  35.0         1
# 4      male  35.0         0
# ..      ...   ...       ...
# 886    male  27.0         0
# 887  female  19.0         1
# 888  female   NaN         0
# 889    male  26.0         1
# 890    male  32.0         0
#
# [891 rows x 3 columns]

# %% [markdown]
# # 가족 크기 변수 추가

# %%
titanic["family_size"] = titanic["sibsp"] + titanic["parch"] + 1

# %% [markdown]
# # 혼자인지 여부

# %%
titanic["is_alone"] = (titanic["family_size"] == 1).astype(int)

# %% [markdown]
# # 3등석이면서 남자인 승객

# %%
titanic[(titanic["pclass"] == 3) & (titanic["sex"] == "male")]
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3  male  22.0      1      0   7.2500        S  Third
# 4           0       3  male  35.0      0      0   8.0500        S  Third
# 5           0       3  male   NaN      0      0   8.4583        Q  Third
# 7           0       3  male   2.0      3      1  21.0750        S  Third
# 12          0       3  male  20.0      0      0   8.0500        S  Third
# ..        ...     ...   ...   ...    ...    ...      ...      ...    ...
# 877         0       3  male  19.0      0      0   7.8958        S  Third
# 878         0       3  male   NaN      0      0   7.8958        S  Third
# 881         0       3  male  33.0      0      0   7.8958        S  Third
# 884         0       3  male  25.0      0      0   7.0500        S  Third
# 890         0       3  male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male deck  embark_town alive  alone  family_size  is_alone
# ...

# %% [markdown]
# # 1등석이면서 여성인 생존자

# %%
titanic[(titanic["pclass"] == 1) & (titanic["sex"] == "female") & (titanic["survived"] == 1)]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 1           1       1  female  38.0      1      0   71.2833        C  First
# 3           1       1  female  35.0      1      0   53.1000        S  First
# 11          1       1  female  58.0      0      0   26.5500        S  First
# 31          1       1  female   NaN      1      0  146.5208        C  First
# 52          1       1  female  49.0      1      0   76.7292        C  First
# ..        ...     ...     ...   ...    ...    ...       ...      ...    ...
# 856         1       1  female  45.0      1      1  164.8667        S  First
# 862         1       1  female  48.0      0      0   25.9292        S  First
# 871         1       1  female  47.0      1      1   52.5542        S  First
# 879         1       1  female  56.0      0      1   83.1583        C  First
# 887         1       1  female  19.0      0      0   30.0000        S  First
#
# ...

# %% [markdown]
# 그룹화 및 평균 계산

# %% [markdown]
# # 선실 등급별 평균 생존률

# %%
titanic.groupby("pclass")["survived"].mean()
# Out:
# pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: survived, dtype: float64

# %% [markdown]
# # 성별과 등급별 생존률

# %%
titanic.groupby(["sex", "pclass"])["survived"].mean()
# Out:
# sex     pclass
# female  1         0.968085
#         2         0.921053
#         3         0.500000
# male    1         0.368852
#         2         0.157407
#         3         0.135447
# Name: survived, dtype: float64

# %% [markdown]
# # 컬럼별 결측치 개수

# %%
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# family_size      0
# is_alone         0
# dtype: int64

# %% [markdown]
# # 생존한 승객만

# %%
titanic[titanic["survived"] == 1]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
# ...

# %% [markdown]
# # 연령대를 카테고리화

# %%
titanic["age_group"] = pd.cut(
    titanic["age"],
    bins=[0, 12, 18, 35, 60, 100],
    labels=["Child", "Teen", "Young Adult", "Adult", "Senior"]
)

# %% [markdown]
# # 요금 순으로 정렬해서 상위 5명 보기

# %%
titanic.sort_values(by="fare", ascending=False).head(5)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 679         1       1    male  36.0      0      1  512.3292        C  First
# 258         1       1  female  35.0      0      0  512.3292        C  First
# 737         1       1    male  35.0      0      0  512.3292        C  First
# 88          1       1  female  23.0      3      2  263.0000        S  First
# 438         0       1    male  64.0      1      4  263.0000        S  First
#
#        who  adult_male deck  embark_town alive  alone  family_size  is_alone  \
# 679    man        True    B    Cherbourg   yes  False            2         0
# 258  woman       False  NaN    Cherbourg   yes   True            1         1
# 737    man        True    B    Cherbourg   yes   True            1         1
# 88   woman       False    C  Southampton   yes  False            6         0
# 438    man        True    C  Southampton    no  False            6         0
#
#        age_group
# 679        Adult
# ...

# %% [markdown]
# # 전체 승객 수

# %%
len(titanic)
# Out:
# 891

# %% [markdown]
# # 생존자 수

# %%
titanic["survived"].sum()
# Out:
# np.int64(342)

# %% [markdown]
# # 생존률

# %%
titanic["survived"].mean()
# Out:
# np.float64(0.3838383838383838)

# %% [markdown]
# #성별로 생존률 비교

# %%
titanic.groupby("sex")["survived"].mean()
# Out:
# sex
# female    0.742038
# male      0.188908
# Name: survived, dtype: float64

# %% [markdown]
# #각 선실 등급(pclass)의 평균 나이

# %%
titanic.groupby("pclass")["age"].mean()
# Out:
# pclass
# 1    38.233441
# 2    29.877630
# 3    25.140620
# Name: age, dtype: float64

# %% [markdown]
# ##종료
